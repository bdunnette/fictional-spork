# %% [markdown]
# <a href="https://colab.research.google.com/github/bdunnette/fictional-spork/blob/master/ml5_lstm_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy scipy tensorflow beautifulsoup4 requests
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (1.16.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (1.3.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.6/dist-packages (1.14.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.21.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.33.4)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.7.1)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.1.7)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow) (41.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (0.15.4)

# %%
import tensorflow as tf
from tensorflow.contrib import rnn
from tensorflow.contrib import legacy_seq2seq

import numpy as np

class Model():
    def __init__(self, args, training=True):
        self.args = args
        if not training:
            args.batch_size = 1
            args.seq_length = 1

        if args.model == 'rnn':
            cell_fn = rnn.BasicRNNCell
        elif args.model == 'gru':
            cell_fn = rnn.GRUCell
        elif args.model == 'lstm':
            cell_fn = rnn.BasicLSTMCell
        elif args.model == 'nas':
            cell_fn = rnn.NASCell
        else:
            raise Exception("model type not supported: {}".format(args.model))

        cells = []
        for _ in range(args.num_layers):
            cell = cell_fn(args.rnn_size)
            if training and (args.output_keep_prob < 1.0 or args.input_keep_prob < 1.0):
                cell = rnn.DropoutWrapper(cell,
                                          input_keep_prob=args.input_keep_prob,
                                          output_keep_prob=args.output_keep_prob)
            cells.append(cell)

        self.cell = cell = rnn.MultiRNNCell(cells, state_is_tuple=True)

        self.input_data = tf.placeholder(
            tf.int32, [args.batch_size, args.seq_length])
        self.targets = tf.placeholder(
            tf.int32, [args.batch_size, args.seq_length])
        self.initial_state = cell.zero_state(args.batch_size, tf.float32)

        with tf.variable_scope('rnnlm'):
            softmax_w = tf.get_variable("softmax_w",
                                        [args.rnn_size, args.vocab_size])
            softmax_b = tf.get_variable("softmax_b", [args.vocab_size])

        embedding = tf.get_variable("embedding", [args.vocab_size, args.rnn_size])
        inputs = tf.nn.embedding_lookup(embedding, self.input_data)

        # dropout beta testing: double check which one should affect next line
        if training and args.output_keep_prob:
            inputs = tf.nn.dropout(inputs, args.output_keep_prob)

        inputs = tf.split(inputs, args.seq_length, 1)
        inputs = [tf.squeeze(input_, [1]) for input_ in inputs]

        def loop(prev, _):
            prev = tf.matmul(prev, softmax_w) + softmax_b
            prev_symbol = tf.stop_gradient(tf.argmax(prev, 1))
            return tf.nn.embedding_lookup(embedding, prev_symbol)

        outputs, last_state = legacy_seq2seq.rnn_decoder(inputs, self.initial_state, cell, loop_function=loop if not training else None, scope='rnnlm')
        output = tf.reshape(tf.concat(outputs, 1), [-1, args.rnn_size])


        self.logits = tf.matmul(output, softmax_w) + softmax_b
        self.probs = tf.nn.softmax(self.logits)
        loss = legacy_seq2seq.sequence_loss_by_example(
                [self.logits],
                [tf.reshape(self.targets, [-1])],
                [tf.ones([args.batch_size * args.seq_length])])
        with tf.name_scope('cost'):
            self.cost = tf.reduce_sum(loss) / args.batch_size / args.seq_length
        self.final_state = last_state
        self.lr = tf.Variable(0.0, trainable=False)
        tvars = tf.trainable_variables()
        grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars),
                args.grad_clip)
        with tf.name_scope('optimizer'):
            optimizer = tf.train.AdamOptimizer(self.lr)
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

        # instrument tensorboard
        tf.summary.histogram('logits', self.logits)
        tf.summary.histogram('loss', loss)
        tf.summary.scalar('train_loss', self.cost)

    def sample(self, sess, chars, vocab, num=200, prime='The ', sampling_type=1):
        state = sess.run(self.cell.zero_state(1, tf.float32))
        for char in prime[:-1]:
            x = np.zeros((1, 1))
            x[0, 0] = vocab[char]
            feed = {self.input_data: x, self.initial_state: state}
            [state] = sess.run([self.final_state], feed)

        def weighted_pick(weights):
            t = np.cumsum(weights)
            s = np.sum(weights)
            return(int(np.searchsorted(t, np.random.rand(1)*s)))

        ret = prime
        char = prime[-1]
        for n in range(num):
            x = np.zeros((1, 1))
            x[0, 0] = vocab[char]
            feed = {self.input_data: x, self.initial_state: state}
            [probs, state] = sess.run([self.probs, self.final_state], feed)
            p = probs[0]

            if sampling_type == 0:
                sample = np.argmax(p)
            elif sampling_type == 2:
                if char == ' ':
                    sample = weighted_pick(p)
                else:
                    sample = np.argmax(p)
            else:  # sampling_type == 1 default:
                sample = weighted_pick(p)

            pred = chars[sample]
            ret += pred
            char = pred
        return ret

# %%
import codecs
import os
import collections
from six.moves import cPickle
import numpy as np


class TextLoader():
    def __init__(self, data_dir, batch_size, seq_length, encoding='utf-8'):
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.seq_length = seq_length
        self.encoding = encoding

        input_file = os.path.join(data_dir, "input.txt")
        vocab_file = os.path.join(data_dir, "vocab.pkl")
        tensor_file = os.path.join(data_dir, "data.npy")

        if not (os.path.exists(vocab_file) and os.path.exists(tensor_file)):
            print("Here we go! Reading text file...")
            self.preprocess(input_file, vocab_file, tensor_file)
        else:
            print("Loading preprocessed files")
            self.load_preprocessed(vocab_file, tensor_file)
        self.create_batches()
        self.reset_batch_pointer()

    def preprocess(self, input_file, vocab_file, tensor_file):
        with codecs.open(input_file, "r", encoding=self.encoding) as f:
            data = f.read()
        counter = collections.Counter(data)
        count_pairs = sorted(counter.items(), key=lambda x: -x[1])
        self.chars, _ = zip(*count_pairs)
        self.vocab_size = len(self.chars)
        self.vocab = dict(zip(self.chars, range(len(self.chars))))
        with open(vocab_file, 'wb') as f:
            cPickle.dump(self.chars, f)
        self.tensor = np.array(list(map(self.vocab.get, data)))
        np.save(tensor_file, self.tensor)

    def load_preprocessed(self, vocab_file, tensor_file):
        with open(vocab_file, 'rb') as f:
            self.chars = cPickle.load(f)
        self.vocab_size = len(self.chars)
        self.vocab = dict(zip(self.chars, range(len(self.chars))))
        self.tensor = np.load(tensor_file)
        self.num_batches = int(self.tensor.size / (self.batch_size *
                                                   self.seq_length))

    def create_batches(self):
        self.num_batches = int(self.tensor.size / (self.batch_size *
                                                   self.seq_length))

        # When the data (tensor) is too small,
        # let's give them a better error message
        if self.num_batches == 0:
            assert False, "Not enough data. Make seq_length and batch_size small."

        self.tensor = self.tensor[:self.num_batches * self.batch_size * self.seq_length]
        xdata = self.tensor
        ydata = np.copy(self.tensor)
        ydata[:-1] = xdata[1:]
        ydata[-1] = xdata[0]
        self.x_batches = np.split(xdata.reshape(self.batch_size, -1),
                                  self.num_batches, 1)
        self.y_batches = np.split(ydata.reshape(self.batch_size, -1),
                                  self.num_batches, 1)

    def next_batch(self):
        x, y = self.x_batches[self.pointer], self.y_batches[self.pointer]
        self.pointer += 1
        return x, y

    def reset_batch_pointer(self):
        self.pointer = 0

# %%
"""
ml5js
A script to dump tensorflow checkpoint variables to tensorflow.js.

This script takes a checkpoint file and writes all of the variables in the
checkpoint to a directory.

"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import json
import os
import re
import string
import tensorflow as tf

OPTIONS = {
  "output_dir": './models/lstm/',
  "remove_variables_regex": '.*Adam.*|.*beta.*',
}
FILENAME_CHARS = string.ascii_letters + string.digits + '_'

def _var_name_to_filename(var_name):
  chars = []
  for c in var_name:
    if c in FILENAME_CHARS:
      chars.append(c)
    elif c == '/':
      chars.append('_')
  return ''.join(chars)

def dump_checkpoints(checkpoint_path, model_path ,vocab, model_name, final_model):
  print('Converting model to ml5js:', model_name, final_model)
  chk_fpath = os.path.expanduser('./{}/{}/{}'.format(checkpoint_path, model_name, final_model))
  reader = tf.train.NewCheckpointReader(chk_fpath)
  var_to_shape_map = reader.get_variable_to_shape_map()
  output_dir = os.path.expanduser(OPTIONS["output_dir"])
  output_dir = './{}/{}'.format(model_path, model_name)
  tf.gfile.MakeDirs(output_dir)
  manifest = {}
  remove_vars_compiled_re = re.compile(OPTIONS["remove_variables_regex"])

  var_filenames_strs = []
  for name in var_to_shape_map:
    if (OPTIONS["remove_variables_regex"] and
        re.match(remove_vars_compiled_re, name)) or name == 'global_step':
      continue
    var_filename = _var_name_to_filename(name)
    manifest[name] = {'filename': var_filename, 'shape': var_to_shape_map[name]}

    # print('Writing variable ' + name + '...')
    tensor = reader.get_tensor(name)
    with open(os.path.join(output_dir, var_filename), 'wb') as f:
      f.write(tensor.tobytes())

    var_filenames_strs.append("\"" + var_filename + "\"")

  # save the vocab
  vocab_fpath = os.path.join(output_dir, 'vocab.json')
  # print('Writing vocab to ' + vocab_fpath)
  with open(vocab_fpath, 'w') as f:
    f.write(json.dumps(vocab, indent=2, sort_keys=True))

  # save the manifest
  manifest_fpath = os.path.join(output_dir, 'manifest.json')
  # print('Writing manifest to ' + manifest_fpath)
  with open(manifest_fpath, 'w') as f:
    f.write(json.dumps(manifest, indent=2, sort_keys=True))
  print('Done! The output model is in', model_path)
  print('Check https://ml5js.org/docs/training-lstm for more information.')

# %%
from bs4 import BeautifulSoup
import os
import requests
import string
import re
import random

model_name = "derby_names"
file_name = "{}/input.txt".format(model_name)
training_file = file_name
name_set = set()
session = requests.Session()

def clean_name(text):
#   strip whitespace and remove parentheticals
  return re.sub(r" ?\([^)]+\)", "", text.strip())
  
url1 = "https://www.twoevils.org/rollergirls/"
print("Getting names from {}".format(url1))
r1 = session.get(url1)
d1 = r1.text
soup1 = BeautifulSoup(d1, "lxml")
rows1 = soup1.find_all('tr', {'class':['trc1', 'trc2']})

for idx, row in enumerate(rows1):
    td = row.find('td')
    name = clean_name(td.get_text())
    name_set.add(name)
    
print("Downloaded {} names".format(len(name_set)))

url2 = "http://www.derbyrollcall.com/everyone"
print("Getting names from {}".format(url2))
r2 = session.get(url2)
d2 = r2.text
soup2 = BeautifulSoup(d2, "lxml")
rows2 = soup2.find_all('td', {'class':'name'})

for idx, td in enumerate(rows2):
    name = clean_name(td.get_text())
    name_set.add(name)

print("Downloaded {} names".format(len(name_set)))
    
initial_letters = string.ascii_uppercase
# Loop through initial letters (A-Z)
for letter in initial_letters:
  url3 = "https://rollerderbyroster.com/view-names/?ini={}".format(letter)
  print("Getting names from {}".format(url3))
  r3 = session.get(url3)
  d3 = r3.text
  soup3 = BeautifulSoup(d3, "lxml")
  
  rows3 = soup3.find_all('ul')
  # Use only last unordered list - this is where names are!
  for idx, li in enumerate(rows3[-1]):
    # Name should be the text of the link within the list item
    name = clean_name(li.find('a').get_text())
#     print(name)
    name_set.add(name)
  print("Downloaded {} names".format(len(name_set)))    

os.makedirs(model_name,exist_ok=True)
with open(training_file,"w") as names_file:
    name_list = list(name_set)
    print("Writing {} names to {}".format(len(name_list),training_file))
#     name_list.sort()
    random.shuffle(name_list)
    names_file.writelines("%s\n" % n for n in name_list)
#     files.download(training_file)
# Out:
# Getting names from https://www.twoevils.org/rollergirls/
# Downloaded 40509 names
# Getting names from http://www.derbyrollcall.com/everyone
# Downloaded 69290 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=A
# Downloaded 69397 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=B
# Downloaded 69635 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=C
# Downloaded 69790 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=D
# Downloaded 70006 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=E
# Downloaded 70058 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=F
# Downloaded 70158 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=G
# Downloaded 70234 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=H
# Downloaded 70365 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=I
# Downloaded 70416 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=J
# Downloaded 70531 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=K
# Downloaded 70649 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=L
# Downloaded 70871 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=M
# Downloaded 71060 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=N
# Downloaded 71111 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=O
# Downloaded 71155 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=P
# Downloaded 71271 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=Q
# Downloaded 71282 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=R
# Downloaded 71437 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=S
# Downloaded 71793 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=T
# Downloaded 71924 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=U
# Downloaded 71929 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=V
# Downloaded 71988 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=W
# Downloaded 72048 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=X
# Downloaded 72051 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=Y
# Downloaded 72057 names
# Getting names from https://rollerderbyroster.com/view-names/?ini=Z
# Downloaded 72065 names
# Writing 72065 names to derby_names/input.txt

# %%
"""
Multi-layer Recurrent Neural Networks (LSTM, RNN) for 
character-level language models in Python using Tensorflow 
and modified to work with tensorflow.js and ml5.js

Based on https://github.com/sherjilozair/char-rnn-tensorflow.
 
This script will train and dump the checkpoints to javascript
"""

from __future__ import print_function
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import tensorflow as tf
import logging

import argparse
import time
import glob
from six.moves import cPickle

# from utils import TextLoader
# from model import Model
from pprint import pprint

from six import text_type
# from json_checkpoint_vars import dump_checkpoints

# hide logs
tf.logging.set_verbosity(tf.logging.ERROR)

def main():
    parser = argparse.ArgumentParser(
                        formatter_class=argparse.ArgumentDefaultsHelpFormatter)
    parser.add_argument('--data_dir', type=str, default=model_name,
                        help='data directory containing input.txt')
    parser.add_argument('--save_model', type=str, default='models',
                        help='directory to store the ml5js model')
    parser.add_argument('--save_checkpoints', type=str, default='checkpoints',
                        help='directory to store checkpointed models')
    parser.add_argument('--log_dir', type=str, default='logs',
                        help='directory to store tensorboard logs')
    parser.add_argument('--rnn_size', type=int, default=128,
                        help='size of RNN hidden state')
    parser.add_argument('--num_layers', type=int, default=2,
                        help='number of layers in the RNN')
    parser.add_argument('--model', type=str, default='lstm',
                        help='rnn, gru, lstm, or nas')
    parser.add_argument('--batch_size', type=int, default=50,
                        help='minibatch size')
    parser.add_argument('--seq_length', type=int, default=50,
                        help='RNN sequence length')
    parser.add_argument('--num_epochs', type=int, default=50,
                        help='number of epochs')
    parser.add_argument('--save_every', type=int, default=1000,
                        help='save frequency')
    parser.add_argument('--grad_clip', type=float, default=5.,
                        help='clip gradients at this value')
    parser.add_argument('--learning_rate', type=float, default=0.002,
                        help='learning rate')
    parser.add_argument('--decay_rate', type=float, default=0.97,
                        help='decay rate for rmsprop')
    parser.add_argument('--output_keep_prob', type=float, default=1.0,
                        help='probability of keeping weights in the hidden layer')
    parser.add_argument('--input_keep_prob', type=float, default=1.0,
                        help='probability of keeping weights in the input layer')
    parser.add_argument('--init_from', type=str, default=None,
                        help="""continue training from saved model at this path. Path must contain files saved by previous training process:
                            'config.pkl'        : configuration;
                            'chars_vocab.pkl'   : vocabulary definitions;
                            'checkpoint'        : paths to model file(s) (created by tf).
                                                  Note: this file contains absolute paths, be careful when moving files around;
                            'model.ckpt-*'      : file(s) with model definition (created by tf)
                        """)
    args = parser.parse_args(args=[])
    train(args)

def getModelVocab(path, model_name):
    # print("Getting the model's vocabulary")
    with open(os.path.join(path, model_name, 'chars_vocab.pkl'), 'rb') as f:
        chars, vocab = cPickle.load(f)
    return vocab

def train(args):
    model_name = args.data_dir.split("/")[-1]
    # make a dir to store checkpoints
    args.save_dir = os.path.join(args.save_checkpoints, model_name)
    os.makedirs(args.save_dir,exist_ok=True)
    
    data_loader = TextLoader(args.data_dir, args.batch_size, args.seq_length)
    args.vocab_size = data_loader.vocab_size

    # check compatibility if training is continued from previously saved model
    if args.init_from is not None:
        # check if all necessary files exist
        assert os.path.isdir(args.init_from)," %s must be a a path" % args.init_from
        assert os.path.isfile(os.path.join(args.init_from,"config.pkl")),"config.pkl file does not exist in path %s"%args.init_from
        assert os.path.isfile(os.path.join(args.init_from,"chars_vocab.pkl")),"chars_vocab.pkl.pkl file does not exist in path %s" % args.init_from
        ckpt = tf.train.get_checkpoint_state(args.init_from)
        assert ckpt, "No checkpoint found"
        assert ckpt.model_checkpoint_path, "No model path found in checkpoint"

        # open old config and check if models are compatible
        with open(os.path.join(args.init_from, 'config.pkl'), 'rb') as f:
            saved_model_args = cPickle.load(f)
        need_be_same = ["model", "rnn_size", "num_layers", "seq_length"]
        for checkme in need_be_same:
            assert vars(saved_model_args)[checkme]==vars(args)[checkme],"Command line argument and saved model disagree on '%s' "%checkme

        # open saved vocab/dict and check if vocabs/dicts are compatible
        with open(os.path.join(args.init_from, 'chars_vocab.pkl'), 'rb') as f:
            saved_chars, saved_vocab = cPickle.load(f)
        assert saved_chars==data_loader.chars, "Data and loaded model disagree on character set!"
        assert saved_vocab==data_loader.vocab, "Data and loaded model disagree on dictionary mappings!"

    if not os.path.isdir(args.save_dir):
        os.makedirs(args.save_dir)
    with open(os.path.join(args.save_dir, 'config.pkl'), 'wb') as f:
        cPickle.dump(args, f)
    with open(os.path.join(args.save_dir, 'chars_vocab.pkl'), 'wb') as f:
        cPickle.dump((data_loader.chars, data_loader.vocab), f)

    model = Model(args)

    with tf.Session() as sess:
        # instrument for tensorboard
        summaries = tf.summary.merge_all()
        writer = tf.summary.FileWriter(
                os.path.join(args.log_dir, time.strftime("%Y-%m-%d-%H-%M-%S")))
        writer.add_graph(sess.graph)

        sess.run(tf.global_variables_initializer())
        saver = tf.train.Saver(tf.global_variables())
        # restore model
        if args.init_from is not None:
            saver.restore(sess, ckpt.model_checkpoint_path)
        for e in range(args.num_epochs):
            sess.run(tf.assign(model.lr, args.learning_rate * (args.decay_rate ** e)))
            data_loader.reset_batch_pointer()
            state = sess.run(model.initial_state)
            for b in range(data_loader.num_batches):
                start = time.time()
                x, y = data_loader.next_batch()
                feed = {model.input_data: x, model.targets: y}
                for i, (c, h) in enumerate(model.initial_state):
                    feed[c] = state[i].c
                    feed[h] = state[i].h

                # instrument for tensorboard
                summ, train_loss, state, _ = sess.run([summaries, model.cost, model.final_state, model.train_op], feed)
                writer.add_summary(summ, e * data_loader.num_batches + b)

                end = time.time()
                print("{}/{} (epoch {}), train_loss = {:.3f}, time/batch = {:.3f}"
                      .format(e * data_loader.num_batches + b,
                              args.num_epochs * data_loader.num_batches,
                              e, train_loss, end - start))

                if (e * data_loader.num_batches + b) % args.save_every == 0\
                        or (e == args.num_epochs-1 and b == data_loader.num_batches-1):
                    # remove previous checkpoints
                    current_checkpoints = [f for f in os.listdir(args.save_dir) if os.path.isfile(os.path.join(args.save_dir, f))]
                    for f in current_checkpoints:
                        if model_name in f:
                            os.remove(os.path.join(args.save_dir, f))
                    # save for the last result
                    checkpoint_path = os.path.join(args.save_dir, model_name)
                    saver.save(sess, checkpoint_path, global_step=e * data_loader.num_batches + b)
                    final_model = '{}-{}'.format(model_name, e * data_loader.num_batches + b)
                    print("Model saved to {}!".format(checkpoint_path))

    # get the vocab
    model_vocab = getModelVocab(args.save_checkpoints, model_name)
    # dump the checkpoints to javascript
    dump_checkpoints(args.save_checkpoints, args.save_model, model_vocab, model_name, final_model)

if __name__ == '__main__':
    main()
# Out:
# Here we go! Reading text file...
# 0/19700 (epoch 0), train_loss = 5.162, time/batch = 1.417
# Model saved to checkpoints/derby_names/derby_names!
# 1/19700 (epoch 0), train_loss = 5.140, time/batch = 0.037
# 2/19700 (epoch 0), train_loss = 5.104, time/batch = 0.036
# 3/19700 (epoch 0), train_loss = 4.980, time/batch = 0.039
# 4/19700 (epoch 0), train_loss = 4.654, time/batch = 0.034
# 5/19700 (epoch 0), train_loss = 4.217, time/batch = 0.032
# 6/19700 (epoch 0), train_loss = 3.973, time/batch = 0.033
# 7/19700 (epoch 0), train_loss = 3.829, time/batch = 0.032
# 8/19700 (epoch 0), train_loss = 3.720, time/batch = 0.027
# 9/19700 (epoch 0), train_loss = 3.704, time/batch = 0.027
# 10/19700 (epoch 0), train_loss = 3.626, time/batch = 0.028
# 11/19700 (epoch 0), train_loss = 3.650, time/batch = 0.028
# 12/19700 (epoch 0), train_loss = 3.543, time/batch = 0.027
# 13/19700 (epoch 0), train_loss = 3.562, time/batch = 0.027
# 14/19700 (epoch 0), train_loss = 3.498, time/batch = 0.033
# 15/19700 (epoch 0), train_loss = 3.525, time/batch = 0.027
# 16/19700 (epoch 0), train_loss = 3.502, time/batch = 0.028
# 17/19700 (epoch 0), train_loss = 3.502, time/batch = 0.027
# 18/19700 (epoch 0), train_loss = 3.531, time/batch = 0.027
# 19/19700 (epoch 0), train_loss = 3.503, time/batch = 0.027
# 20/19700 (epoch 0), train_loss = 3.480, time/batch = 0.027
# 21/19700 (epoch 0), train_loss = 3.516, time/batch = 0.027
# 22/19700 (epoch 0), train_loss = 3.543, time/batch = 0.033
# 23/19700 (epoch 0), train_loss = 3.509, time/batch = 0.026
# 24/19700 (epoch 0), train_loss = 3.502, time/batch = 0.029
# 25/19700 (epoch 0), train_loss = 3.524, time/batch = 0.027
# 26/19700 (epoch 0), train_loss = 3.500, time/batch = 0.027
# 27/19700 (epoch 0), train_loss = 3.526, time/batch = 0.027
# 28/19700 (epoch 0), train_loss = 3.505, time/batch = 0.027
# 29/19700 (epoch 0), train_loss = 3.532, time/batch = 0.028
# 30/19700 (epoch 0), train_loss = 3.486, time/batch = 0.030
# 31/19700 (epoch 0), train_loss = 3.548, time/batch = 0.027
# 32/19700 (epoch 0), train_loss = 3.465, time/batch = 0.028
# 33/19700 (epoch 0), train_loss = 3.492, time/batch = 0.031
# 34/19700 (epoch 0), train_loss = 3.510, time/batch = 0.041
# 35/19700 (epoch 0), train_loss = 3.483, time/batch = 0.028
# 36/19700 (epoch 0), train_loss = 3.518, time/batch = 0.027
# 37/19700 (epoch 0), train_loss = 3.514, time/batch = 0.036
# 38/19700 (epoch 0), train_loss = 3.502, time/batch = 0.032
# 39/19700 (epoch 0), train_loss = 3.518, time/batch = 0.027
# 40/19700 (epoch 0), train_loss = 3.501, time/batch = 0.027
# 41/19700 (epoch 0), train_loss = 3.502, time/batch = 0.027
# 42/19700 (epoch 0), train_loss = 3.508, time/batch = 0.027
# 43/19700 (epoch 0), train_loss = 3.515, time/batch = 0.027
# 44/19700 (epoch 0), train_loss = 3.525, time/batch = 0.028
# 45/19700 (epoch 0), train_loss = 3.498, time/batch = 0.031
# 46/19700 (epoch 0), train_loss = 3.540, time/batch = 0.029
# 47/19700 (epoch 0), train_loss = 3.464, time/batch = 0.027
# 48/19700 (epoch 0), train_loss = 3.470, time/batch = 0.027
# 49/19700 (epoch 0), train_loss = 3.474, time/batch = 0.027
# 50/19700 (epoch 0), train_loss = 3.506, time/batch = 0.027
# 51/19700 (epoch 0), train_loss = 3.466, time/batch = 0.026
# 52/19700 (epoch 0), train_loss = 3.449, time/batch = 0.028
# 53/19700 (epoch 0), train_loss = 3.506, time/batch = 0.032
# 54/19700 (epoch 0), train_loss = 3.478, time/batch = 0.028
# 55/19700 (epoch 0), train_loss = 3.471, time/batch = 0.026
# 56/19700 (epoch 0), train_loss = 3.528, time/batch = 0.027
# 57/19700 (epoch 0), train_loss = 3.511, time/batch = 0.027
# 58/19700 (epoch 0), train_loss = 3.542, time/batch = 0.027
# 59/19700 (epoch 0), train_loss = 3.545, time/batch = 0.027
# 60/19700 (epoch 0), train_loss = 3.513, time/batch = 0.028
# 61/19700 (epoch 0), train_loss = 3.500, time/batch = 0.031
# 62/19700 (epoch 0), train_loss = 3.490, time/batch = 0.027
# 63/19700 (epoch 0), train_loss = 3.505, time/batch = 0.031
# 64/19700 (epoch 0), train_loss = 3.485, time/batch = 0.027
# 65/19700 (epoch 0), train_loss = 3.526, time/batch = 0.027
# 66/19700 (epoch 0), train_loss = 3.472, time/batch = 0.027
# 67/19700 (epoch 0), train_loss = 3.516, time/batch = 0.027
# 68/19700 (epoch 0), train_loss = 3.513, time/batch = 0.027
# 69/19700 (epoch 0), train_loss = 3.517, time/batch = 0.030
# 70/19700 (epoch 0), train_loss = 3.502, time/batch = 0.028
# 71/19700 (epoch 0), train_loss = 3.490, time/batch = 0.027
# 72/19700 (epoch 0), train_loss = 3.502, time/batch = 0.027
# 73/19700 (epoch 0), train_loss = 3.479, time/batch = 0.028
# 74/19700 (epoch 0), train_loss = 3.487, time/batch = 0.037
# 75/19700 (epoch 0), train_loss = 3.469, time/batch = 0.027
# 76/19700 (epoch 0), train_loss = 3.470, time/batch = 0.029
# 77/19700 (epoch 0), train_loss = 3.475, time/batch = 0.031
# 78/19700 (epoch 0), train_loss = 3.507, time/batch = 0.027
# 79/19700 (epoch 0), train_loss = 3.469, time/batch = 0.027
# 80/19700 (epoch 0), train_loss = 3.512, time/batch = 0.027
# 81/19700 (epoch 0), train_loss = 3.486, time/batch = 0.029
# 82/19700 (epoch 0), train_loss = 3.503, time/batch = 0.027
# 83/19700 (epoch 0), train_loss = 3.496, time/batch = 0.027
# 84/19700 (epoch 0), train_loss = 3.535, time/batch = 0.034
# 85/19700 (epoch 0), train_loss = 3.504, time/batch = 0.028
# 86/19700 (epoch 0), train_loss = 3.471, time/batch = 0.028
# 87/19700 (epoch 0), train_loss = 3.460, time/batch = 0.027
# 88/19700 (epoch 0), train_loss = 3.482, time/batch = 0.027
# 89/19700 (epoch 0), train_loss = 3.495, time/batch = 0.027
# 90/19700 (epoch 0), train_loss = 3.447, time/batch = 0.027
# 91/19700 (epoch 0), train_loss = 3.489, time/batch = 0.027
# 92/19700 (epoch 0), train_loss = 3.469, time/batch = 0.032
# 93/19700 (epoch 0), train_loss = 3.439, time/batch = 0.028
# 94/19700 (epoch 0), train_loss = 3.463, time/batch = 0.027
# 95/19700 (epoch 0), train_loss = 3.429, time/batch = 0.027
# 96/19700 (epoch 0), train_loss = 3.430, time/batch = 0.027
# 97/19700 (epoch 0), train_loss = 3.479, time/batch = 0.027
# 98/19700 (epoch 0), train_loss = 3.462, time/batch = 0.027
# 99/19700 (epoch 0), train_loss = 3.456, time/batch = 0.031
# 100/19700 (epoch 0), train_loss = 3.385, time/batch = 0.036
# 101/19700 (epoch 0), train_loss = 3.397, time/batch = 0.027
# 102/19700 (epoch 0), train_loss = 3.409, time/batch = 0.029
# 103/19700 (epoch 0), train_loss = 3.378, time/batch = 0.028
# 104/19700 (epoch 0), train_loss = 3.386, time/batch = 0.028
# 105/19700 (epoch 0), train_loss = 3.384, time/batch = 0.027
# 106/19700 (epoch 0), train_loss = 3.365, time/batch = 0.028
# 107/19700 (epoch 0), train_loss = 3.342, time/batch = 0.027
# 108/19700 (epoch 0), train_loss = 3.306, time/batch = 0.031
# 109/19700 (epoch 0), train_loss = 3.340, time/batch = 0.032
# 110/19700 (epoch 0), train_loss = 3.303, time/batch = 0.032
# 111/19700 (epoch 0), train_loss = 3.306, time/batch = 0.027
# 112/19700 (epoch 0), train_loss = 3.304, time/batch = 0.029
# 113/19700 (epoch 0), train_loss = 3.271, time/batch = 0.027
# 114/19700 (epoch 0), train_loss = 3.278, time/batch = 0.029
# 115/19700 (epoch 0), train_loss = 3.266, time/batch = 0.033
# 116/19700 (epoch 0), train_loss = 3.238, time/batch = 0.028
# 117/19700 (epoch 0), train_loss = 3.216, time/batch = 0.027
# 118/19700 (epoch 0), train_loss = 3.202, time/batch = 0.027
# 119/19700 (epoch 0), train_loss = 3.233, time/batch = 0.028
# 120/19700 (epoch 0), train_loss = 3.191, time/batch = 0.029
# 121/19700 (epoch 0), train_loss = 3.213, time/batch = 0.027
# 122/19700 (epoch 0), train_loss = 3.197, time/batch = 0.028
# 123/19700 (epoch 0), train_loss = 3.197, time/batch = 0.033
# 124/19700 (epoch 0), train_loss = 3.113, time/batch = 0.027
# 125/19700 (epoch 0), train_loss = 3.152, time/batch = 0.028
# 126/19700 (epoch 0), train_loss = 3.167, time/batch = 0.028
# 127/19700 (epoch 0), train_loss = 3.107, time/batch = 0.028
# 128/19700 (epoch 0), train_loss = 3.131, time/batch = 0.028
# 129/19700 (epoch 0), train_loss = 3.069, time/batch = 0.028
# 130/19700 (epoch 0), train_loss = 3.122, time/batch = 0.029
# 131/19700 (epoch 0), train_loss = 3.085, time/batch = 0.032
# 132/19700 (epoch 0), train_loss = 3.182, time/batch = 0.028
# 133/19700 (epoch 0), train_loss = 3.130, time/batch = 0.030
# 134/19700 (epoch 0), train_loss = 3.125, time/batch = 0.028
# 135/19700 (epoch 0), train_loss = 3.116, time/batch = 0.028
# 136/19700 (epoch 0), train_loss = 3.070, time/batch = 0.028
# 137/19700 (epoch 0), train_loss = 3.124, time/batch = 0.028
# 138/19700 (epoch 0), train_loss = 3.136, time/batch = 0.028
# 139/19700 (epoch 0), train_loss = 3.113, time/batch = 0.031
# 140/19700 (epoch 0), train_loss = 3.074, time/batch = 0.029
# 141/19700 (epoch 0), train_loss = 3.101, time/batch = 0.029
# 142/19700 (epoch 0), train_loss = 3.095, time/batch = 0.028
# 143/19700 (epoch 0), train_loss = 3.043, time/batch = 0.031
# 144/19700 (epoch 0), train_loss = 3.064, time/batch = 0.028
# 145/19700 (epoch 0), train_loss = 3.038, time/batch = 0.037
# 146/19700 (epoch 0), train_loss = 3.031, time/batch = 0.034
# 147/19700 (epoch 0), train_loss = 3.075, time/batch = 0.028
# 148/19700 (epoch 0), train_loss = 2.979, time/batch = 0.029
# 149/19700 (epoch 0), train_loss = 3.033, time/batch = 0.029
# 150/19700 (epoch 0), train_loss = 3.055, time/batch = 0.032
# 151/19700 (epoch 0), train_loss = 3.032, time/batch = 0.030
# 152/19700 (epoch 0), train_loss = 3.000, time/batch = 0.029
# 153/19700 (epoch 0), train_loss = 3.057, time/batch = 0.037
# 154/19700 (epoch 0), train_loss = 2.990, time/batch = 0.029
# 155/19700 (epoch 0), train_loss = 3.004, time/batch = 0.028
# 156/19700 (epoch 0), train_loss = 2.971, time/batch = 0.028
# 157/19700 (epoch 0), train_loss = 3.017, time/batch = 0.029
# 158/19700 (epoch 0), train_loss = 2.996, time/batch = 0.029
# 159/19700 (epoch 0), train_loss = 2.971, time/batch = 0.029
# 160/19700 (epoch 0), train_loss = 3.016, time/batch = 0.029
# 161/19700 (epoch 0), train_loss = 2.978, time/batch = 0.032
# 162/19700 (epoch 0), train_loss = 2.996, time/batch = 0.029
# 163/19700 (epoch 0), train_loss = 2.998, time/batch = 0.030
# 164/19700 (epoch 0), train_loss = 2.956, time/batch = 0.029
# 165/19700 (epoch 0), train_loss = 2.924, time/batch = 0.029
# 166/19700 (epoch 0), train_loss = 2.958, time/batch = 0.029
# 167/19700 (epoch 0), train_loss = 2.934, time/batch = 0.033
# 168/19700 (epoch 0), train_loss = 2.947, time/batch = 0.029
# 169/19700 (epoch 0), train_loss = 2.944, time/batch = 0.031
# 170/19700 (epoch 0), train_loss = 2.903, time/batch = 0.030
# 171/19700 (epoch 0), train_loss = 2.910, time/batch = 0.029
# 172/19700 (epoch 0), train_loss = 2.973, time/batch = 0.029
# 173/19700 (epoch 0), train_loss = 2.946, time/batch = 0.029
# 174/19700 (epoch 0), train_loss = 2.922, time/batch = 0.033
# 175/19700 (epoch 0), train_loss = 2.975, time/batch = 0.029
# 176/19700 (epoch 0), train_loss = 2.927, time/batch = 0.032
# 177/19700 (epoch 0), train_loss = 2.946, time/batch = 0.029
# 178/19700 (epoch 0), train_loss = 2.915, time/batch = 0.035
# 179/19700 (epoch 0), train_loss = 2.934, time/batch = 0.034
# 180/19700 (epoch 0), train_loss = 2.948, time/batch = 0.029
# 181/19700 (epoch 0), train_loss = 2.965, time/batch = 0.033
# 182/19700 (epoch 0), train_loss = 2.924, time/batch = 0.033
# 183/19700 (epoch 0), train_loss = 2.869, time/batch = 0.028
# 184/19700 (epoch 0), train_loss = 2.918, time/batch = 0.029
# 185/19700 (epoch 0), train_loss = 2.918, time/batch = 0.029
# 186/19700 (epoch 0), train_loss = 2.930, time/batch = 0.029
# 187/19700 (epoch 0), train_loss = 2.885, time/batch = 0.029
# 188/19700 (epoch 0), train_loss = 2.914, time/batch = 0.034
# 189/19700 (epoch 0), train_loss = 2.959, time/batch = 0.032
# 190/19700 (epoch 0), train_loss = 2.859, time/batch = 0.029
# 191/19700 (epoch 0), train_loss = 2.921, time/batch = 0.029
# 192/19700 (epoch 0), train_loss = 2.866, time/batch = 0.029
# 193/19700 (epoch 0), train_loss = 2.904, time/batch = 0.029
# 194/19700 (epoch 0), train_loss = 2.897, time/batch = 0.029
# 195/19700 (epoch 0), train_loss = 2.889, time/batch = 0.036
# 196/19700 (epoch 0), train_loss = 2.859, time/batch = 0.030
# 197/19700 (epoch 0), train_loss = 2.830, time/batch = 0.029
# 198/19700 (epoch 0), train_loss = 2.946, time/batch = 0.029
# 199/19700 (epoch 0), train_loss = 2.857, time/batch = 0.029
# 245/19700 (epoch 0), train_loss = 2.835, time/batch = 0.033
# 246/19700 (epoch 0), train_loss = 2.794, time/batch = 0.029
# 247/19700 (epoch 0), train_loss = 2.809, time/batch = 0.030
# 248/19700 (epoch 0), train_loss = 2.806, time/batch = 0.029
# 249/19700 (epoch 0), train_loss = 2.764, time/batch = 0.030
# 250/19700 (epoch 0), train_loss = 2.765, time/batch = 0.031
# 251/19700 (epoch 0), train_loss = 2.794, time/batch = 0.038
# 252/19700 (epoch 0), train_loss = 2.851, time/batch = 0.029
# 253/19700 (epoch 0), train_loss = 2.795, time/batch = 0.030
# 254/19700 (epoch 0), train_loss = 2.750, time/batch = 0.029
# 255/19700 (epoch 0), train_loss = 2.767, time/batch = 0.029
# 256/19700 (epoch 0), train_loss = 2.797, time/batch = 0.030
# 257/19700 (epoch 0), train_loss = 2.801, time/batch = 0.030
# 258/19700 (epoch 0), train_loss = 2.799, time/batch = 0.034
# 259/19700 (epoch 0), train_loss = 2.847, time/batch = 0.029
# 260/19700 (epoch 0), train_loss = 2.794, time/batch = 0.032
# 261/19700 (epoch 0), train_loss = 2.757, time/batch = 0.029
# 262/19700 (epoch 0), train_loss = 2.787, time/batch = 0.029
# 263/19700 (epoch 0), train_loss = 2.839, time/batch = 0.030
# 264/19700 (epoch 0), train_loss = 2.736, time/batch = 0.030
# 265/19700 (epoch 0), train_loss = 2.806, time/batch = 0.033
# 266/19700 (epoch 0), train_loss = 2.858, time/batch = 0.030
# 267/19700 (epoch 0), train_loss = 2.778, time/batch = 0.031
# 268/19700 (epoch 0), train_loss = 2.773, time/batch = 0.029
# 269/19700 (epoch 0), train_loss = 2.790, time/batch = 0.030
# 270/19700 (epoch 0), train_loss = 2.852, time/batch = 0.029
# 271/19700 (epoch 0), train_loss = 2.748, time/batch = 0.029
# 272/19700 (epoch 0), train_loss = 2.787, time/batch = 0.034
# 273/19700 (epoch 0), train_loss = 2.782, time/batch = 0.032
# 274/19700 (epoch 0), train_loss = 2.754, time/batch = 0.029
# 275/19700 (epoch 0), train_loss = 2.739, time/batch = 0.029
# 276/19700 (epoch 0), train_loss = 2.822, time/batch = 0.030
# 277/19700 (epoch 0), train_loss = 2.714, time/batch = 0.030
# 278/19700 (epoch 0), train_loss = 2.759, time/batch = 0.039
# 279/19700 (epoch 0), train_loss = 2.766, time/batch = 0.035
# 280/19700 (epoch 0), train_loss = 2.745, time/batch = 0.030
# 281/19700 (epoch 0), train_loss = 2.796, time/batch = 0.030
# 282/19700 (epoch 0), train_loss = 2.783, time/batch = 0.030
# 283/19700 (epoch 0), train_loss = 2.801, time/batch = 0.030
# 284/19700 (epoch 0), train_loss = 2.745, time/batch = 0.029
# 285/19700 (epoch 0), train_loss = 2.777, time/batch = 0.029
# 286/19700 (epoch 0), train_loss = 2.806, time/batch = 0.037
# 287/19700 (epoch 0), train_loss = 2.735, time/batch = 0.029
# 288/19700 (epoch 0), train_loss = 2.778, time/batch = 0.029
# 289/19700 (epoch 0), train_loss = 2.732, time/batch = 0.029
# 290/19700 (epoch 0), train_loss = 2.784, time/batch = 0.029
# 793/19700 (epoch 2), train_loss = 2.475, time/batch = 0.030
# 794/19700 (epoch 2), train_loss = 2.511, time/batch = 0.030
# 795/19700 (epoch 2), train_loss = 2.473, time/batch = 0.034
# 796/19700 (epoch 2), train_loss = 2.491, time/batch = 0.032
# 797/19700 (epoch 2), train_loss = 2.511, time/batch = 0.035
# 798/19700 (epoch 2), train_loss = 2.512, time/batch = 0.029
# 799/19700 (epoch 2), train_loss = 2.514, time/batch = 0.030
# ...
# 19450/19700 (epoch 49), train_loss = 2.031, time/batch = 0.031
# 19451/19700 (epoch 49), train_loss = 1.995, time/batch = 0.033
# 19452/19700 (epoch 49), train_loss = 2.022, time/batch = 0.037
# 19453/19700 (epoch 49), train_loss = 1.992, time/batch = 0.033
# 19454/19700 (epoch 49), train_loss = 1.977, time/batch = 0.032
# 19455/19700 (epoch 49), train_loss = 2.016, time/batch = 0.032
# 19456/19700 (epoch 49), train_loss = 2.020, time/batch = 0.032
# 19457/19700 (epoch 49), train_loss = 2.019, time/batch = 0.032
# 19458/19700 (epoch 49), train_loss = 1.974, time/batch = 0.032
# 19459/19700 (epoch 49), train_loss = 2.018, time/batch = 0.036
# 19460/19700 (epoch 49), train_loss = 2.014, time/batch = 0.035
# 19461/19700 (epoch 49), train_loss = 1.929, time/batch = 0.032
# 19462/19700 (epoch 49), train_loss = 1.965, time/batch = 0.032
# 19463/19700 (epoch 49), train_loss = 2.012, time/batch = 0.032
# 19464/19700 (epoch 49), train_loss = 1.960, time/batch = 0.032
# 19465/19700 (epoch 49), train_loss = 1.982, time/batch = 0.032
# 19466/19700 (epoch 49), train_loss = 2.053, time/batch = 0.041
# 19467/19700 (epoch 49), train_loss = 1.998, time/batch = 0.032
# 19468/19700 (epoch 49), train_loss = 1.975, time/batch = 0.032
# 19469/19700 (epoch 49), train_loss = 1.975, time/batch = 0.032
# 19470/19700 (epoch 49), train_loss = 1.958, time/batch = 0.032
# 19471/19700 (epoch 49), train_loss = 1.978, time/batch = 0.032
# 19472/19700 (epoch 49), train_loss = 1.981, time/batch = 0.032
# 19473/19700 (epoch 49), train_loss = 1.961, time/batch = 0.037
# 19474/19700 (epoch 49), train_loss = 1.965, time/batch = 0.032
# 19475/19700 (epoch 49), train_loss = 1.923, time/batch = 0.033
# 19476/19700 (epoch 49), train_loss = 1.947, time/batch = 0.032
# 19477/19700 (epoch 49), train_loss = 1.994, time/batch = 0.035
# 19478/19700 (epoch 49), train_loss = 2.044, time/batch = 0.035
# 19479/19700 (epoch 49), train_loss = 2.024, time/batch = 0.037
# 19480/19700 (epoch 49), train_loss = 1.982, time/batch = 0.033
# 19481/19700 (epoch 49), train_loss = 2.085, time/batch = 0.033
# 19482/19700 (epoch 49), train_loss = 2.012, time/batch = 0.032
# 19483/19700 (epoch 49), train_loss = 1.976, time/batch = 0.032
# 19484/19700 (epoch 49), train_loss = 1.962, time/batch = 0.032
# 19485/19700 (epoch 49), train_loss = 1.949, time/batch = 0.032
# 19486/19700 (epoch 49), train_loss = 1.987, time/batch = 0.036
# 19487/19700 (epoch 49), train_loss = 2.032, time/batch = 0.034
# 19488/19700 (epoch 49), train_loss = 2.006, time/batch = 0.031
# 19489/19700 (epoch 49), train_loss = 1.972, time/batch = 0.032
# 19490/19700 (epoch 49), train_loss = 2.004, time/batch = 0.032
# 19491/19700 (epoch 49), train_loss = 1.988, time/batch = 0.032
# 19492/19700 (epoch 49), train_loss = 2.055, time/batch = 0.032
# 19493/19700 (epoch 49), train_loss = 1.979, time/batch = 0.038
# 19494/19700 (epoch 49), train_loss = 1.994, time/batch = 0.032
# 19495/19700 (epoch 49), train_loss = 2.033, time/batch = 0.032
# 19496/19700 (epoch 49), train_loss = 1.930, time/batch = 0.032
# 19497/19700 (epoch 49), train_loss = 2.027, time/batch = 0.032
# 19498/19700 (epoch 49), train_loss = 1.959, time/batch = 0.032
# 19499/19700 (epoch 49), train_loss = 2.042, time/batch = 0.032
# 19500/19700 (epoch 49), train_loss = 1.995, time/batch = 0.037
# 19501/19700 (epoch 49), train_loss = 1.967, time/batch = 0.031
# 19502/19700 (epoch 49), train_loss = 1.968, time/batch = 0.032
# 19503/19700 (epoch 49), train_loss = 1.953, time/batch = 0.032
# 19504/19700 (epoch 49), train_loss = 2.011, time/batch = 0.032
# 19505/19700 (epoch 49), train_loss = 1.979, time/batch = 0.032
# 19506/19700 (epoch 49), train_loss = 1.934, time/batch = 0.032
# 19507/19700 (epoch 49), train_loss = 2.008, time/batch = 0.035
# 19508/19700 (epoch 49), train_loss = 2.007, time/batch = 0.042
# 19509/19700 (epoch 49), train_loss = 1.997, time/batch = 0.032
# 19510/19700 (epoch 49), train_loss = 1.969, time/batch = 0.032
# 19511/19700 (epoch 49), train_loss = 1.990, time/batch = 0.032
# 19512/19700 (epoch 49), train_loss = 2.040, time/batch = 0.032
# 19513/19700 (epoch 49), train_loss = 2.002, time/batch = 0.036
# 19514/19700 (epoch 49), train_loss = 2.027, time/batch = 0.036
# 19515/19700 (epoch 49), train_loss = 1.986, time/batch = 0.033
# 19516/19700 (epoch 49), train_loss = 2.001, time/batch = 0.032
# 19517/19700 (epoch 49), train_loss = 1.953, time/batch = 0.032
# 19518/19700 (epoch 49), train_loss = 1.934, time/batch = 0.032
# 19519/19700 (epoch 49), train_loss = 1.957, time/batch = 0.033
# 19520/19700 (epoch 49), train_loss = 2.048, time/batch = 0.039
# 19521/19700 (epoch 49), train_loss = 1.982, time/batch = 0.032
# 19522/19700 (epoch 49), train_loss = 1.983, time/batch = 0.032
# 19523/19700 (epoch 49), train_loss = 1.975, time/batch = 0.032
# 19524/19700 (epoch 49), train_loss = 1.974, time/batch = 0.031
# 19525/19700 (epoch 49), train_loss = 2.028, time/batch = 0.032
# 19526/19700 (epoch 49), train_loss = 2.008, time/batch = 0.032
# 19527/19700 (epoch 49), train_loss = 1.979, time/batch = 0.036
# 19528/19700 (epoch 49), train_loss = 2.025, time/batch = 0.032
# 19529/19700 (epoch 49), train_loss = 1.998, time/batch = 0.032
# 19530/19700 (epoch 49), train_loss = 1.998, time/batch = 0.032
# 19531/19700 (epoch 49), train_loss = 1.944, time/batch = 0.032
# 19532/19700 (epoch 49), train_loss = 2.021, time/batch = 0.032
# 19533/19700 (epoch 49), train_loss = 2.010, time/batch = 0.032
# 19534/19700 (epoch 49), train_loss = 2.025, time/batch = 0.034
# 19535/19700 (epoch 49), train_loss = 2.017, time/batch = 0.034
# 19536/19700 (epoch 49), train_loss = 1.954, time/batch = 0.032
# 19537/19700 (epoch 49), train_loss = 2.002, time/batch = 0.032
# 19538/19700 (epoch 49), train_loss = 1.940, time/batch = 0.032
# 19539/19700 (epoch 49), train_loss = 2.009, time/batch = 0.041
# 19540/19700 (epoch 49), train_loss = 2.008, time/batch = 0.034
# 19541/19700 (epoch 49), train_loss = 1.944, time/batch = 0.036
# 19542/19700 (epoch 49), train_loss = 1.919, time/batch = 0.032
# 19543/19700 (epoch 49), train_loss = 1.960, time/batch = 0.032
# 19544/19700 (epoch 49), train_loss = 1.956, time/batch = 0.032
# 19545/19700 (epoch 49), train_loss = 1.981, time/batch = 0.032
# 19546/19700 (epoch 49), train_loss = 2.034, time/batch = 0.032
# 19547/19700 (epoch 49), train_loss = 2.003, time/batch = 0.038
# 19548/19700 (epoch 49), train_loss = 2.022, time/batch = 0.032
# 19549/19700 (epoch 49), train_loss = 1.969, time/batch = 0.032
# 19550/19700 (epoch 49), train_loss = 1.858, time/batch = 0.032
# 19551/19700 (epoch 49), train_loss = 2.019, time/batch = 0.031
# 19552/19700 (epoch 49), train_loss = 1.961, time/batch = 0.032
# 19553/19700 (epoch 49), train_loss = 1.980, time/batch = 0.032
# 19554/19700 (epoch 49), train_loss = 1.976, time/batch = 0.035
# 19555/19700 (epoch 49), train_loss = 1.914, time/batch = 0.032
# 19556/19700 (epoch 49), train_loss = 1.933, time/batch = 0.032
# 19557/19700 (epoch 49), train_loss = 2.014, time/batch = 0.032
# 19558/19700 (epoch 49), train_loss = 2.045, time/batch = 0.032
# 19559/19700 (epoch 49), train_loss = 2.023, time/batch = 0.032
# 19560/19700 (epoch 49), train_loss = 1.965, time/batch = 0.032
# 19561/19700 (epoch 49), train_loss = 2.003, time/batch = 0.035
# 19562/19700 (epoch 49), train_loss = 1.973, time/batch = 0.047
# 19563/19700 (epoch 49), train_loss = 1.984, time/batch = 0.037
# 19564/19700 (epoch 49), train_loss = 1.970, time/batch = 0.032
# 19565/19700 (epoch 49), train_loss = 2.011, time/batch = 0.033
# 19566/19700 (epoch 49), train_loss = 2.008, time/batch = 0.032
# 19567/19700 (epoch 49), train_loss = 1.994, time/batch = 0.035
# 19568/19700 (epoch 49), train_loss = 2.011, time/batch = 0.035
# 19569/19700 (epoch 49), train_loss = 1.988, time/batch = 0.039
# 19570/19700 (epoch 49), train_loss = 1.963, time/batch = 0.032
# 19571/19700 (epoch 49), train_loss = 2.023, time/batch = 0.032
# 19572/19700 (epoch 49), train_loss = 2.023, time/batch = 0.033
# 19573/19700 (epoch 49), train_loss = 2.020, time/batch = 0.037
# 19574/19700 (epoch 49), train_loss = 2.000, time/batch = 0.034
# 19575/19700 (epoch 49), train_loss = 2.032, time/batch = 0.032
# 19576/19700 (epoch 49), train_loss = 2.061, time/batch = 0.032
# 19577/19700 (epoch 49), train_loss = 1.870, time/batch = 0.032
# 19578/19700 (epoch 49), train_loss = 2.027, time/batch = 0.032
# 19579/19700 (epoch 49), train_loss = 2.043, time/batch = 0.032
# 19580/19700 (epoch 49), train_loss = 1.968, time/batch = 0.036
# 19581/19700 (epoch 49), train_loss = 1.932, time/batch = 0.032
# 19582/19700 (epoch 49), train_loss = 2.049, time/batch = 0.032
# 19583/19700 (epoch 49), train_loss = 1.935, time/batch = 0.034
# 19584/19700 (epoch 49), train_loss = 1.989, time/batch = 0.032
# 19585/19700 (epoch 49), train_loss = 2.022, time/batch = 0.032
# 19586/19700 (epoch 49), train_loss = 1.958, time/batch = 0.032
# 19587/19700 (epoch 49), train_loss = 1.965, time/batch = 0.034
# 19588/19700 (epoch 49), train_loss = 2.013, time/batch = 0.033
# 19589/19700 (epoch 49), train_loss = 2.029, time/batch = 0.033
# 19590/19700 (epoch 49), train_loss = 2.031, time/batch = 0.032
# 19591/19700 (epoch 49), train_loss = 2.011, time/batch = 0.032
# 19592/19700 (epoch 49), train_loss = 2.045, time/batch = 0.032
# 19593/19700 (epoch 49), train_loss = 1.962, time/batch = 0.032
# 19594/19700 (epoch 49), train_loss = 1.991, time/batch = 0.035
# 19595/19700 (epoch 49), train_loss = 1.964, time/batch = 0.033
# 19596/19700 (epoch 49), train_loss = 1.998, time/batch = 0.032
# 19597/19700 (epoch 49), train_loss = 1.986, time/batch = 0.032
# 19598/19700 (epoch 49), train_loss = 2.005, time/batch = 0.034
# 19599/19700 (epoch 49), train_loss = 1.927, time/batch = 0.031
# 19600/19700 (epoch 49), train_loss = 1.973, time/batch = 0.043
# 19601/19700 (epoch 49), train_loss = 1.955, time/batch = 0.035
# 19602/19700 (epoch 49), train_loss = 2.010, time/batch = 0.032
# 19603/19700 (epoch 49), train_loss = 2.025, time/batch = 0.032
# 19604/19700 (epoch 49), train_loss = 1.978, time/batch = 0.032
# 19605/19700 (epoch 49), train_loss = 1.974, time/batch = 0.033
# 19606/19700 (epoch 49), train_loss = 1.961, time/batch = 0.032
# 19607/19700 (epoch 49), train_loss = 1.995, time/batch = 0.039
# 19608/19700 (epoch 49), train_loss = 2.029, time/batch = 0.034
# 19609/19700 (epoch 49), train_loss = 1.949, time/batch = 0.034
# 19610/19700 (epoch 49), train_loss = 2.058, time/batch = 0.032
# 19611/19700 (epoch 49), train_loss = 2.027, time/batch = 0.034
# 19612/19700 (epoch 49), train_loss = 2.036, time/batch = 0.033
# 19613/19700 (epoch 49), train_loss = 1.962, time/batch = 0.032
# 19614/19700 (epoch 49), train_loss = 2.003, time/batch = 0.037
# 19615/19700 (epoch 49), train_loss = 1.978, time/batch = 0.032
# 19616/19700 (epoch 49), train_loss = 2.025, time/batch = 0.032
# 19617/19700 (epoch 49), train_loss = 1.903, time/batch = 0.032
# 19618/19700 (epoch 49), train_loss = 2.014, time/batch = 0.032
# 19619/19700 (epoch 49), train_loss = 1.986, time/batch = 0.032
# 19620/19700 (epoch 49), train_loss = 2.010, time/batch = 0.032
# 19621/19700 (epoch 49), train_loss = 1.963, time/batch = 0.035
# 19622/19700 (epoch 49), train_loss = 1.951, time/batch = 0.033
# 19623/19700 (epoch 49), train_loss = 2.001, time/batch = 0.032
# 19624/19700 (epoch 49), train_loss = 1.956, time/batch = 0.032
# 19625/19700 (epoch 49), train_loss = 1.991, time/batch = 0.033
# 19626/19700 (epoch 49), train_loss = 1.995, time/batch = 0.032
# 19627/19700 (epoch 49), train_loss = 2.020, time/batch = 0.032
# 19628/19700 (epoch 49), train_loss = 1.990, time/batch = 0.038
# 19629/19700 (epoch 49), train_loss = 2.073, time/batch = 0.033
# 19630/19700 (epoch 49), train_loss = 2.033, time/batch = 0.035
# 19631/19700 (epoch 49), train_loss = 1.977, time/batch = 0.035
# 19632/19700 (epoch 49), train_loss = 2.012, time/batch = 0.033
# 19633/19700 (epoch 49), train_loss = 1.995, time/batch = 0.033
# 19634/19700 (epoch 49), train_loss = 1.954, time/batch = 0.033
# 19635/19700 (epoch 49), train_loss = 1.985, time/batch = 0.037
# 19636/19700 (epoch 49), train_loss = 1.943, time/batch = 0.033
# 19637/19700 (epoch 49), train_loss = 1.959, time/batch = 0.032
# 19638/19700 (epoch 49), train_loss = 1.988, time/batch = 0.032
# 19639/19700 (epoch 49), train_loss = 1.916, time/batch = 0.033
# 19640/19700 (epoch 49), train_loss = 2.012, time/batch = 0.032
# 19641/19700 (epoch 49), train_loss = 1.965, time/batch = 0.037
# 19642/19700 (epoch 49), train_loss = 1.910, time/batch = 0.034
# 19643/19700 (epoch 49), train_loss = 1.938, time/batch = 0.032
# 19644/19700 (epoch 49), train_loss = 1.990, time/batch = 0.032
# 19645/19700 (epoch 49), train_loss = 1.989, time/batch = 0.032
# 19646/19700 (epoch 49), train_loss = 1.979, time/batch = 0.032
# 19647/19700 (epoch 49), train_loss = 2.058, time/batch = 0.032
# 19648/19700 (epoch 49), train_loss = 1.933, time/batch = 0.050
# 19649/19700 (epoch 49), train_loss = 2.002, time/batch = 0.038
# 19650/19700 (epoch 49), train_loss = 2.024, time/batch = 0.032
# 19651/19700 (epoch 49), train_loss = 1.946, time/batch = 0.034
# 19652/19700 (epoch 49), train_loss = 1.989, time/batch = 0.032
# 19653/19700 (epoch 49), train_loss = 2.012, time/batch = 0.032
# 19654/19700 (epoch 49), train_loss = 1.982, time/batch = 0.034
# 19655/19700 (epoch 49), train_loss = 1.968, time/batch = 0.034
# 19656/19700 (epoch 49), train_loss = 1.982, time/batch = 0.032
# 19657/19700 (epoch 49), train_loss = 1.995, time/batch = 0.033
# 19658/19700 (epoch 49), train_loss = 1.993, time/batch = 0.032
# 19659/19700 (epoch 49), train_loss = 1.969, time/batch = 0.032
# 19660/19700 (epoch 49), train_loss = 2.001, time/batch = 0.036
# 19661/19700 (epoch 49), train_loss = 2.031, time/batch = 0.040
# 19662/19700 (epoch 49), train_loss = 1.951, time/batch = 0.032
# 19663/19700 (epoch 49), train_loss = 1.969, time/batch = 0.035
# 19664/19700 (epoch 49), train_loss = 2.068, time/batch = 0.033
# 19665/19700 (epoch 49), train_loss = 2.025, time/batch = 0.032
# 19666/19700 (epoch 49), train_loss = 2.053, time/batch = 0.035
# 19667/19700 (epoch 49), train_loss = 2.026, time/batch = 0.038
# 19668/19700 (epoch 49), train_loss = 1.976, time/batch = 0.035
# 19669/19700 (epoch 49), train_loss = 2.061, time/batch = 0.033
# 19670/19700 (epoch 49), train_loss = 2.001, time/batch = 0.032
# 19671/19700 (epoch 49), train_loss = 1.913, time/batch = 0.033
# 19672/19700 (epoch 49), train_loss = 2.005, time/batch = 0.036
# 19673/19700 (epoch 49), train_loss = 1.983, time/batch = 0.032
# 19674/19700 (epoch 49), train_loss = 1.983, time/batch = 0.035
# 19675/19700 (epoch 49), train_loss = 2.018, time/batch = 0.032
# 19676/19700 (epoch 49), train_loss = 1.982, time/batch = 0.032
# 19677/19700 (epoch 49), train_loss = 1.995, time/batch = 0.032
# 19678/19700 (epoch 49), train_loss = 1.980, time/batch = 0.032
# 19679/19700 (epoch 49), train_loss = 1.984, time/batch = 0.037
# 19680/19700 (epoch 49), train_loss = 2.021, time/batch = 0.036
# 19681/19700 (epoch 49), train_loss = 2.032, time/batch = 0.033
# 19682/19700 (epoch 49), train_loss = 1.985, time/batch = 0.033
# 19683/19700 (epoch 49), train_loss = 2.014, time/batch = 0.032
# 19684/19700 (epoch 49), train_loss = 2.012, time/batch = 0.033
# 19685/19700 (epoch 49), train_loss = 1.986, time/batch = 0.032
# 19686/19700 (epoch 49), train_loss = 1.940, time/batch = 0.038
# 19687/19700 (epoch 49), train_loss = 2.042, time/batch = 0.032
# 19688/19700 (epoch 49), train_loss = 2.081, time/batch = 0.032
# 19689/19700 (epoch 49), train_loss = 2.019, time/batch = 0.032
# 19690/19700 (epoch 49), train_loss = 1.929, time/batch = 0.035
# 19691/19700 (epoch 49), train_loss = 1.977, time/batch = 0.036
# 19692/19700 (epoch 49), train_loss = 2.020, time/batch = 0.033
# 19693/19700 (epoch 49), train_loss = 2.033, time/batch = 0.040
# 19694/19700 (epoch 49), train_loss = 2.081, time/batch = 0.032
# 19695/19700 (epoch 49), train_loss = 1.988, time/batch = 0.032
# 19696/19700 (epoch 49), train_loss = 1.946, time/batch = 0.032
# 19697/19700 (epoch 49), train_loss = 1.961, time/batch = 0.032
# 19698/19700 (epoch 49), train_loss = 2.034, time/batch = 0.033
# 19699/19700 (epoch 49), train_loss = 1.991, time/batch = 0.033
# Model saved to checkpoints/derby_names/derby_names!
# Converting model to ml5js: derby_names derby_names-19699
# Done! The output model is in models
# Check https://ml5js.org/docs/training-lstm for more information.

# %%
import os
import zipfile

dir_name = 'models/{}'.format(model_name)
filePaths = []

for root, directories, files in os.walk(dir_name):
    for filename in files:
        # Create the full filepath by using os module.
        filePath = os.path.join(root, filename)
        filePaths.append(filePath)

zip_file = zipfile.ZipFile(dir_name+'.zip', 'w')
with zip_file:
  # writing each file one by one
  for file in filePaths:
    zip_file.write(file)
       
print(dir_name+'.zip file is created successfully!')
# Out:
# models/derby_names.zip file is created successfully!
